# %%
import tensorflow as tf

# %%
from tensorflow.keras.datasets import cifar10

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(f"Training data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")
# Out:
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
from tensorflow.keras.utils import to_categorical

# Normalize pixel values
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 59s 92ms/step - accuracy: 0.3007 - loss: 1.8960 - val_accuracy: 0.5028 - val_loss: 1.4034
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.4868 - loss: 1.4193 - val_accuracy: 0.5835 - val_loss: 1.1883
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 81ms/step - accuracy: 0.5467 - loss: 1.2698 - val_accuracy: 0.6059 - val_loss: 1.1237
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 78ms/step - accuracy: 0.5753 - loss: 1.1882 - val_accuracy: 0.6281 - val_loss: 1.0629
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 76ms/step - accuracy: 0.6033 - loss: 1.1116 - val_accuracy: 0.6396 - val_loss: 1.0255
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 81ms/step - accuracy: 0.6225 - loss: 1.0668 - val_accuracy: 0.6544 - val_loss: 0.9767
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 78ms/step - accuracy: 0.6395 - loss: 1.0154 - val_accuracy: 0.6638 - val_loss: 0.9567
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")

from sklearn.metrics import classification_report
import numpy as np

y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print(classification_report(y_true, y_pred_classes))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6763 - loss: 0.9119
# Test Accuracy: 0.6773
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.74      1000
#            1       0.80      0.81      0.80      1000
#            2       0.62      0.49      0.55      1000
#            3       0.47      0.54      0.51      1000
#            4       0.63      0.55      0.59      1000
#            5       0.56      0.57      0.56      1000
#            6       0.77      0.76      0.77      1000
#            7       0.64      0.79      0.71      1000
#            8       0.83      0.74      0.79      1000
#            9       0.73      0.79      0.76      1000
#
#     accuracy                           0.68     10000
#    macro avg       0.68      0.68      0.68     10000
# weighted avg       0.68      0.68      0.68     10000

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# Calculate the number of samples for validation
num_validation_samples = int(0.2 * x_train.shape[0])

# Split the data into training and validation sets
x_train_split, x_val_split = x_train[:-num_validation_samples], x_train[-num_validation_samples:]
y_train_split, y_val_split = y_train[:-num_validation_samples], y_train[-num_validation_samples:]


# Create data iterators for training and validation sets
train_iterator = datagen.flow(x_train_split, y_train_split, batch_size=64)
validation_iterator = datagen.flow(x_val_split, y_val_split, batch_size=64)

# Retrain with augmentation, using the validation_data argument
model.fit(train_iterator, epochs=10, validation_data=validation_iterator)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 116ms/step - accuracy: 0.5802 - loss: 1.1921 - val_accuracy: 0.6230 - val_loss: 1.0648
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.5916 - loss: 1.1631 - val_accuracy: 0.6318 - val_loss: 1.0456
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 72s 115ms/step - accuracy: 0.5963 - loss: 1.1451 - val_accuracy: 0.6297 - val_loss: 1.0612
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.6072 - loss: 1.1211 - val_accuracy: 0.6461 - val_loss: 1.0129
# Epoch 5/10
# ...

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow
print(tensorflow.__version__)
print(dir(tensorflow))
# Out:
# 2.18.0
# ...
